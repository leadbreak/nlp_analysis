# %%
# 필요한 모듈과 라이브러리를 로딩
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time, os, math, random, sys, datetime
from datetime import date, timedelta, datetime
import pyautogui
from tqdm import tqdm

# chromedriver 자동 설치
import chromedriver_autoinstaller

from selenium.webdriver.common.action_chains import ActionChains

# %%
# 작업 시간과 고유 dir 등 생성
n = time.localtime()
s = '%04d-%02d-%02d' % (n.tm_year, n.tm_mon, n.tm_mday)
s_time = time.time( )


a = datetime.now()-timedelta(days=7)
a = a.strftime('%Y-%m-%d')
b = datetime.now()-timedelta(days=13)
b = b.strftime('%Y-%m-%d')
print(b, a)
# Out:
# 2021-04-23 2021-04-29

# %%
print("=" *80)
print("         OPINION 크롤러입니다.")
print("=" *80)

f_dir = os.path.expanduser('~') +  f'\\Desktop\\crawler-bot\\KEYWORD\\{b}-{a}\\' # 운영체제 상관없이 바탕화면 'crawler-bot' 폴더에 작업

print("=" *80)
print("데이터 크롤링을 시작합니다.")
print("=" *80)
# Out:
# ================================================================================
#          OPINION 크롤러입니다.
# ================================================================================
# ================================================================================
# 데이터 크롤링을 시작합니다.
# ================================================================================

# %%
# 저장될 파일 경로와 이름을 지정
# 파일을 저장할 폴더 위치를 만들고, 중복일 경우 해당 폴더를 삭제하고 새로 생성합니다.
try : 
    os.makedirs(f_dir)
except : pass
else : 
    os.chdir(f_dir)

fc_name=f_dir+'\\'+'keyword_ddanzi.csv'

# %%
# 크롤링 데이터가 들어갈 리스트 생성
domain2 = []    # 크롤링 도메인
keyword2 = []   # 크롤링 키워드
title2 = []     # 게시물 제목
user2 = []      # 게시물 작성자
url2 = []       # 게시물 url
time2 = []      # 게시물 작성 시간
view_cnt2 = []  # 게시물 뷰 카운트
like_cnt2 = []  # 추천/공감 카운트
text2 = []      # 게시물 내용
com_cnt2 = []   # 댓글 수
com_user2 = []  # 댓글 user_id
com_text2 = []  # 댓글 user_id & text

# %%
# chromedriver-autoinstaller 이용
chromedriver_autoinstaller.install(cwd=True)

# HEADLESS MODE
options = webdriver.ChromeOptions()
# options.add_argument('headless')
options.add_argument('window-size=1920x1080') 
# options.add_argument("--disable-gpu")
options.add_experimental_option('excludeSwitches', ['enable-logging'])
options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")
args = ["hide_console", ]

# 알림창 끄기
options.add_experimental_option("prefs", {"profile.default_content_setting_values.notifications": 1})

# 웹사이트 접속 후 해당 메뉴로 이동
driver = webdriver.Chrome(options=options,service_args=args)
driver.maximize_window()

# %%
# 1. 딴지 크롤링
query_url= ('https://www.ddanzi.com/free')

driver.get(query_url)
driver.implicitly_wait(5)

# %%
domain1 = "딴지"
print("==========",domain1,"크롤링 진행 중 ==========")
# Out:
# ========== 딴지 크롤링 진행 중 ==========

# %%
print("로그인을 진행합니다.")

tmp_id = "ddive1041"
tmp_pw = "q1w2e3r4!@"

driver.find_element_by_link_text('로그인').click()
time.sleep(1)
# Out:
# 로그인을 진행합니다.

# %%
# id 입력
driver.find_element_by_xpath('//*[@id="uid"]').click()
for i in tmp_id :
    time.sleep(0.1)
    driver.find_element_by_xpath('//*[@id="uid"]').send_keys(i)
    
# pw 입력    
driver.find_element_by_xpath('//*[@id="upw"]').click()
for j in tmp_pw :
    time.sleep(0.1)
    driver.find_element_by_xpath('//*[@id="upw"]').send_keys(j)
    
driver.find_element_by_xpath('//*[@id="regularsubmit"]/td/button').click()
time.sleep(1)

# %%
keyword = "이낙연"  # 현재 크롤링 키워드

page_num = 1        # 현재 페이지 넘버

driver.get(f"https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword={keyword}&page={page_num}")
driver.implicitly_wait(10)
time.sleep(3)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
item_box = soup.find_all(name='tbody')[-1].find_all('tr')
# item_box

# %%
for item in item_box :
    try : # 공지글만 class가 있음, 공지글 제외
        item['class']
    except :
        print(item.find(name='td', attrs={'class':'time'}))
# Out:
# <td class="time">13:02:28</td>
# <td class="time">08:00:32</td>
# <td class="time">07:33:09</td>
# <td class="time">04:14:29</td>
# <td class="time">04:08:30</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-05</td>
# <td class="time">2021-05-04</td>
# <td class="time">2021-05-04</td>
# <td class="time">2021-05-04</td>
# <td class="time">2021-05-04</td>
# <td class="time">2021-05-04</td>
# <td class="time">2021-05-04</td>
# <td class="time">2021-05-03</td>
# <td class="time">2021-05-03</td>

# %%
while_code = 0
while True :
    if while_code == 1 :
        break

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    item_box = soup.find_all(name='tbody')[-1].find_all('tr')
    
    post_num = 0
    
    for item in item_box :
        
        try : # 공지글만 class가 있음, 공지글 제외
            item['class']
            post_num += 1
            cut_post_num = post_num
        except :
            post_num += 1
            page_num += 1

            # 크롤링 시작
            post_time = item.find(name='td', attrs={'class':'time'}).text

            # 시간만 표시되는 오늘 게시물이거나, 올해 게시물만 크롤링
            
            if post_time > a :
                time_code = 0
            elif datetime.now().strftime('%Y-%m-%d') == a and ":" in post_time :
                
                print("scout 01")
                time_code = 1 
            elif post_time <= a and post_time >= b  :
                time_code = 1

            else : # 시간 영역이 맞지 않는 경우 time_code=1 로 변경
                time_code = 2

            if time_code == 1 :

                print("크롤링 도메인 : ",domain1)
                print("크롤링 키워드 : ", keyword)

                title1 = item.find(name='td', attrs={'class':'title'}).find('a').text.strip()
                user1 = item.find(name='td', attrs={'class':'author txtleft'}).text.strip()
                url1 = item.find(name='td', attrs={'class':'title'}).find('a')['href']
                time1 = item.find(name='td', attrs={'class':'time'}).text
                view_cnt1 = item.find(name='td', attrs={'class':'readNum'}).text
                like_cnt1 = item.find(name='td', attrs={'class':'voteNum'}).text.strip()
                
                try :
                    com_cnt1 = item.find(name='td', attrs={'class':'title'}).find(name='span', attrs={'class':'talk'}).text.replace("[","").replace("]","").strip()
                except :
                    com_cnt1 = 0

                print("게시물 제목 :", title1)
                print("작성자 :", user1)
                print("게시물 url :", url1)
                print("업로드 시간 :", time1)
                print("조회수 :", view_cnt1)
                print("추천수 :", like_cnt1)
                print("댓글수 :", com_cnt1)
                print("\n")

                domain2.append(domain1)
                keyword2.append(keyword)
                title2.append(title1)
                user2.append(user1)
                url2.append(url1)
                time2.append(time1)
                view_cnt2.append(view_cnt1)
                like_cnt2.append(like_cnt1)
                com_cnt2.append(com_cnt1)    


            elif time_code == 2 :
                if keyword == "이낙연" :
                    print("검색 키워드를 변경합니다.")
                    keyword = "이재명"
                    page_num = 1        # 현재 페이지 넘버
                    driver.get(f"https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword={keyword}&page={page_num}")
                    driver.implicitly_wait(10)
                    time.sleep(3)
                    break
                else :
                    print("1차 게시물 수집을 종료합니다...")
                    print("2차 게시물 수집을 시작합니다...")
                    while_code = 1
                    break
                    
            else :
                
                if post_num == cut_post_num : # 게시물이 나오지 않고 공지만 있는 경우 : 계속 검색으로 우회
                    print("=====   계속 검색을 시도합니다.   =====")
                    driver.find_element_by_link_text("계속 검색").click()
                    driver.implicitly_wait(10)
                    time.sleep(3)
                    page_num = 1
                else :
                    print("=====   다음 페이지로 넘어갑니다.   =====")
                    try :

                        cur_url = driver.current_url        
                        cur_page = int(cur_url.split("&page=")[1][0])
                        print("scout 03 :", cur_url)
                        next_page = cur_page + 1
                        next_url = cur_url.split("&page=")[0] + "&page=" + str(next_page)  + cur_url.split("&page=")[1][1:]
                        print("scout 04 :", cur_url.split("&page="))
                        print("scout 05 :", next_url)
                        driver.get(next_url)
                        driver.implicitly_wait(10)
                        time.sleep(3)

                    except :

                        try :                
                            print("scout 01:", driver.current_url )
                            driver.find_element_by_link_text("2").click()
                            driver.implicitly_wait(10)
                            time.sleep(3)
                            print("scout 02:", driver.current_url )
                        except : # 페이지가 하나밖에 표시되지 않은 경우 - 계속 검색으로 우회
                            print("=====   계속 검색을 시도합니다.   =====")
                            driver.find_element_by_link_text("계속 검색").click()
                            driver.implicitly_wait(10)
                            time.sleep(3)
                            page_num = 1

    
    if post_num == cut_post_num : # 게시물이 나오지 않고 공지만 있는 경우 : 계속 검색으로 우회
        print("=====   계속 검색을 시도합니다.   =====")
        driver.find_element_by_link_text("계속 검색").click()
        driver.implicitly_wait(10)
        time.sleep(3)
        page_num = 1
        
    else :

        try :
            print("=====   다음 페이지로 넘어갑니다.   =====")
            cur_url = driver.current_url        
            cur_page = int(cur_url.split("&page=")[1][0])
            print("scout 03 :", cur_url)
            next_page = cur_page + 1
            next_url = cur_url.split("&page=")[0] + "&page=" + str(next_page)  + cur_url.split("&page=")[1][1:]
            print("scout 04 :", cur_url.split("&page="))
            print("scout 05 :", next_url)
            driver.get(next_url)
            driver.implicitly_wait(10)
            time.sleep(3)
            
        except :

            print("=====   계속 검색을 시도합니다.   =====")
            driver.find_element_by_link_text("계속 검색").click()
            driver.implicitly_wait(10)
            time.sleep(3)
            page_num = 1
# Out:
# 검색 키워드를 변경합니다.
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&page=1
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85', '1']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&page=2
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&page=2
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85', '2']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&page=3
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&page=3
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85', '3']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&page=4
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&page=4
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85', '4']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&page=5
# =====   계속 검색을 시도합니다.   =====
# =====   다음 페이지로 넘어갑니다.   =====
# scout 01: https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746
# scout 02: https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=2&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=2&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '2&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=3&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=3&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '3&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=4&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=4&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '4&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=5&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=5&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '5&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=6&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=6&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '6&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=7&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=7&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '7&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=8&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=8&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '8&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=9&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=9&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '9&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=10&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=10&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '10&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=20&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=20&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '20&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=30&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=30&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '30&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=40&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=40&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '40&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=50&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=50&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '50&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=60&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=60&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '60&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=70&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=70&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '70&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=80&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=80&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '80&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=90&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=90&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '90&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=100&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=100&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '100&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=200&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=200&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '200&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=300&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=300&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '300&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=400&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=400&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '400&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=500&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=500&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '500&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=600&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=600&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '600&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=700&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=700&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '700&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=800&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=800&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '800&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=900&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=900&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '900&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=1000&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=1000&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '1000&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=2000&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=2000&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '2000&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=3000&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=3000&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '3000&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=4000&last_division=-511725076
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=4000&last_division=-511725076
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746', '4000&last_division=-511725076']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511730746&page=5000&last_division=-511725076
# =====   계속 검색을 시도합니다.   =====
# =====   다음 페이지로 넘어갑니다.   =====
# scout 01: https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076
# scout 02: https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=2&last_division=-511719333
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=2&last_division=-511719333
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076', '2&last_division=-511719333']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=3&last_division=-511719333
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=3&last_division=-511719333
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076', '3&last_division=-511719333']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=4&last_division=-511719333
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=4&last_division=-511719333
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076', '4&last_division=-511719333']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=5&last_division=-511719333
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=5&last_division=-511719333
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076', '5&last_division=-511719333']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=6&last_division=-511719333
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=6&last_division=-511719333
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076', '6&last_division=-511719333']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=7&last_division=-511719333
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=7&last_division=-511719333
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076', '7&last_division=-511719333']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=8&last_division=-511719333
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=8&last_division=-511719333
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076', '8&last_division=-511719333']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=9&last_division=-511719333
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=9&last_division=-511719333
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076', '9&last_division=-511719333']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=10&last_division=-511719333
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 모처럼 다음 일면에 이재명. 정봉주 임은정 있네요
# 작성자 : 빵꾸뿡뿡
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679613967
# 업로드 시간 : 2021-04-29
# 조회수 : 211
# 추천수 :
# 댓글수 : 0
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 문재인대통령과 이재명까지만..
# 작성자 : agevoice
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679607393
# 업로드 시간 : 2021-04-29
# 조회수 : 290
# 추천수 : 7
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 지사, '기본소득 목적 국토 보유세' 제안.webp
# 작성자 : geosu
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679601328
# 업로드 시간 : 2021-04-29
# 조회수 : 4383
# 추천수 : 121
# 댓글수 : 69
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명
# 작성자 : 경남좌빨
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679588912
# 업로드 시간 : 2021-04-29
# 조회수 : 289
# 추천수 : 8
# 댓글수 : 4
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 전국조직 출범 예정!
# 작성자 : WithorWithoutYou
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679586165
# 업로드 시간 : 2021-04-29
# 조회수 : 467
# 추천수 : 4
# 댓글수 : 0
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명이 언제 군 가산점 애기를 했다는 거죠???
# 작성자 : 로이거
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679583323
# 업로드 시간 : 2021-04-29
# 조회수 : 106
# 추천수 :
# 댓글수 : 0
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명은 대안이 아니라, 답안 입니다.
# 작성자 : 부곡하와이
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679579072
# 업로드 시간 : 2021-04-29
# 조회수 : 285
# 추천수 : 3
# 댓글수 : 4
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 페이스북 원문엔 '군 가산점'이 없네요
# 작성자 : 기이임밥
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679575427
# 업로드 시간 : 2021-04-29
# 조회수 : 301
# 추천수 : 4
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 "軍가산점 등 지지 못받을 것..청년은 '특혜' 원하지 않아"
# 작성자 : 비아그라가격인하대책위원장
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679573195
# 업로드 시간 : 2021-04-29
# 조회수 : 636
# 추천수 :
# 댓글수 : 11
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 <청년은 특혜 아닌 공정을 원하고 있습니다>
# 작성자 : 지안군
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679550510
# 업로드 시간 : 2021-04-29
# 조회수 : 1857
# 추천수 : 81
# 댓글수 : 12
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 최근에 이재명 지사가 뭐 큰 싸움에서 이겼나요?
# 작성자 : 범돌인가?
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679545550
# 업로드 시간 : 2021-04-29
# 조회수 : 292
# 추천수 :
# 댓글수 : 0
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명으로 차기 대선구도 잡을거면, 대선까진 검찰과 대립은 어렵지않나요?
# 작성자 : 회계학산책
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679544776
# 업로드 시간 : 2021-04-29
# 조회수 : 279
# 추천수 :
# 댓글수 : 3
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : <이재명 백블 워딩 입수>
# 작성자 : 상식있는프로눈팅러
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679532472
# 업로드 시간 : 2021-04-29
# 조회수 : 772
# 추천수 : 13
# 댓글수 : 3
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명▷전국조직 '민주평화광장' 11만명…내달 12일 깃발!◁머투
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679530839
# 업로드 시간 : 2021-04-29
# 조회수 : 276
# 추천수 : 2
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 추미애전장관이든 이재명지사든  둘중누가되든 지지함
# 작성자 : 다스베이더(흡연충)
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679524060
# 업로드 시간 : 2021-04-29
# 조회수 : 141
# 추천수 :
# 댓글수 : 1
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이 타이밍에 이재명은 힘을 보여줘야 합니다
# 작성자 : 알퐁스_도데
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679513953
# 업로드 시간 : 2021-04-29
# 조회수 : 373
# 추천수 : 7
# 댓글수 : 11
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 여론조사▷이재명 24%·윤석열 23% 양강 유지…이낙연 7%[NBS]◁뉴스1
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679512377
# 업로드 시간 : 2021-04-29
# 조회수 : 614
# 추천수 : 1
# 댓글수 : 11
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명의 카리스마! 목소리 높인다고 다가 아냐
# 작성자 : 서둘
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679501984
# 업로드 시간 : 2021-04-29
# 조회수 : 310
# 추천수 : 1
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 관련 세계일보 글이 왜 기레기의 가짜뉴스죠?
# 작성자 : 밥값
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679498102
# 업로드 시간 : 2021-04-29
# 조회수 : 244
# 추천수 :
# 댓글수 : 14
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 당차원에서 이재명지사를 띄웁니까 아니면 정말로 누릅니까????
# 작성자 : 파파존스
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679453160
# 업로드 시간 : 2021-04-29
# 조회수 : 338
# 추천수 :
# 댓글수 : 5
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명의 윤석열 평가 이렇게 생각하시면 되죠
# 작성자 : 기이임밥
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679421977
# 업로드 시간 : 2021-04-28
# 조회수 : 275
# 추천수 : 1
# 댓글수 : 3
#
#
# =====   다음 페이지로 넘어갑니다.   =====
# scout 03 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=10&last_division=-511719333
# scout 04 : ['https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076', '10&last_division=-511719333']
# scout 05 : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&page=20&last_division=-511719333
# =====   계속 검색을 시도합니다.   =====
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 밑에 이재명 윤석열 다룬 세계일보 기사가 말해주는 한 가지 사실요
# 작성자 : 기이임밥
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679397689
# 업로드 시간 : 2021-04-28
# 조회수 : 455
# 추천수 : 7
# 댓글수 : 1
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명: 일본 방사능오염수 방류중단 공동선언
# 작성자 : 서둘
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679396863
# 업로드 시간 : 2021-04-28
# 조회수 : 337
# 추천수 : 10
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명, 윤석열에 "원칙 따라 일잘했다고 생각"
# 작성자 : [N☢]뿌뿌는외로워
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679395371
# 업로드 시간 : 2021-04-28
# 조회수 : 1020
# 추천수 :
# 댓글수 : 30
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 윤석열이 제일 원하는 게 이재명이 자기 공격하는 건데... 말입니다.
# 작성자 : 기이임밥
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679395605
# 업로드 시간 : 2021-04-28
# 조회수 : 363
# 추천수 : 8
# 댓글수 : 1
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명, 윤석열에 "원칙 따라 일 잘했다고 생각"
# 작성자 : redit
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679392849
# 업로드 시간 : 2021-04-28
# 조회수 : 1232
# 추천수 :
# 댓글수 : 28
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 경기도지사 sns
# 작성자 : 雨天☔️JSYK
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679383971
# 업로드 시간 : 2021-04-28
# 조회수 : 910
# 추천수 : 14
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명▷ “눈 가리고 아웅 식 해법 안 통해…반부패·공정 개혁에 박차”◁뉴스1
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679366500
# 업로드 시간 : 2021-04-28
# 조회수 : 276
# 추천수 : 6
# 댓글수 : 3
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 거침없는 윤석열 하이킥.. 2030 지지율, 이재명 제쳤다
# 작성자 : MusicFreak
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679337051
# 업로드 시간 : 2021-04-28
# 조회수 : 646
# 추천수 : 1
# 댓글수 : 7
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 결국 이재명을 지지해야 하는건가...
# 작성자 : originalfinder
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679304978
# 업로드 시간 : 2021-04-28
# 조회수 : 1453
# 추천수 : 22
# 댓글수 : 8
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 김종민▷이재명 비판(봉황이 노는 곳에 뱁새야 오지 마라)◁서경
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679296112
# 업로드 시간 : 2021-04-28
# 조회수 : 839
# 추천수 :
# 댓글수 : 6
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이번 보궐선거 이재명 때문에 졌다는 말 하시는분 있는데?
# 작성자 : 쟁점을파하다
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679279870
# 업로드 시간 : 2021-04-27
# 조회수 : 664
# 추천수 : 2
# 댓글수 : 19
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명씨는 커뮤니티를 많이 둘러보는것 아닌가 싶더군요.
# 작성자 : 맑은-아침
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679279402
# 업로드 시간 : 2021-04-27
# 조회수 : 519
# 추천수 : 8
# 댓글수 : 3
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명▷부동산 투기 근절하고 임대사업자 특혜 폐지하겠습니다◁페북
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679276245
# 업로드 시간 : 2021-04-27
# 조회수 : 473
# 추천수 : 16
# 댓글수 : 5
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 뉴스1▷이재명 “부동산 투기는 만악의 근원, 근절할 것”
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679264986
# 업로드 시간 : 2021-04-27
# 조회수 : 365
# 추천수 : 12
# 댓글수 : 5
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 한겨레▷이재명계 ‘성장과 공정 포럼’ 5월 발족
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679246630
# 업로드 시간 : 2021-04-27
# 조회수 : 256
# 추천수 : 1
# 댓글수 : 6
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 똥파리사이트 "윤석열 47.2%·이재명 40.0%"..양자대결 격차 벌어져"
# 작성자 : 빵꾸뿡뿡
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679248307
# 업로드 시간 : 2021-04-27
# 조회수 : 600
# 추천수 :
# 댓글수 : 1
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 아이24▷이재명, 윤고추에게  "그냥 ‘공정벌금’ 어떻습니까"
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679240228
# 업로드 시간 : 2021-04-27
# 조회수 : 301
# 추천수 : 2
# 댓글수 : 6
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 지사에 대해... 그럼 이길 수 있습니까?
# 작성자 : 크림빵5
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679233562
# 업로드 시간 : 2021-04-27
# 조회수 : 442
# 추천수 : 14
# 댓글수 : 6
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 재산벌금 논쟁 이재명..윤희숙에 감사 글올린 이유.jpgㄷㄷㄷ
# 작성자 : 힙찔찔
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679229317
# 업로드 시간 : 2021-04-27
# 조회수 : 4664
# 추천수 : 71
# 댓글수 : 23
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명은 강하다.
# 작성자 : 스무디앤
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679223986
# 업로드 시간 : 2021-04-27
# 조회수 : 458
# 추천수 : 14
# 댓글수 : 4
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 언론을 안 조질 경우 이재명 지사가 대통렁 돼도 당할 공작입니다(feat 룰라)
# 작성자 : 기이임밥
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679222331
# 업로드 시간 : 2021-04-27
# 조회수 : 265
# 추천수 : 4
# 댓글수 : 3
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 가장 최신 이재명의 전반적 가치관 생각을 알고싶다 하면
# 작성자 : 빵꾸뿡뿡
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679215196
# 업로드 시간 : 2021-04-27
# 조회수 : 232
# 추천수 :
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 오마이▷재산비례벌금제, 이재명 승👍  윤희숙 패👎
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679209981
# 업로드 시간 : 2021-04-27
# 조회수 : 382
# 추천수 : 6
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 하태경 '사실상 이재명 잘 했다고 느낀다'고 전해져
# 작성자 : 무료입장유료퇴장
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679204090
# 업로드 시간 : 2021-04-27
# 조회수 : 606
# 추천수 :
# 댓글수 : 4
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 하태경 "이재명, 백신 혼선 책임 있다..러시아 얘기, 왜 하냐".gisa
# 작성자 : kazama™
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679197862
# 업로드 시간 : 2021-04-27
# 조회수 : 4421
# 추천수 : 39
# 댓글수 : 31
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 스서▷이재명의 당부
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679197449
# 업로드 시간 : 2021-04-27
# 조회수 : 326
# 추천수 : 9
# 댓글수 : 6
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 지사 "공공기관이 폭리 일산대교 통행료 비판"
# 작성자 : 막내야
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679189092
# 업로드 시간 : 2021-04-27
# 조회수 : 354
# 추천수 : 7
# 댓글수 : 6
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 하태가 이재명을 까네요..오!!오..
# 작성자 : 상쾌한전자파
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679170396
# 업로드 시간 : 2021-04-27
# 조회수 : 1108
# 추천수 : 2
# 댓글수 : 0
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 아경▷이재명표 '청년면접수당' 30만원으로 오른다네요, 꼭 챙기소
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679167126
# 업로드 시간 : 2021-04-27
# 조회수 : 383
# 추천수 :
# 댓글수 : 3
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : KTV, 전국 민영방송 - 이재명 지사에게 듣는다
# 작성자 : 서둘
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511719333&document_srl=679124148
# 업로드 시간 : 2021-04-26
# 조회수 : 184
# 추천수 : 4
# 댓글수 : 0
#
#
# =====   다음 페이지로 넘어갑니다.   =====
# =====   계속 검색을 시도합니다.   =====
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 핵직구 ㄷㄷㄷ
# 작성자 : 성남자🐷
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=679032478
# 업로드 시간 : 2021-04-26
# 조회수 : 10158
# 추천수 : 113
# 댓글수 : 18
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 레드준표 "조폭·양아치 리더십"…윤석열·이재명 겨냥?
# 작성자 : 에너자이저bb
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=679024730
# 업로드 시간 : 2021-04-26
# 조회수 : 352
# 추천수 :
# 댓글수 : 3
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 파이낸▷이재명 지사, 윤고추에 "국어 독해력부터 갖춰라"
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=679022947
# 업로드 시간 : 2021-04-26
# 조회수 : 3402
# 추천수 : 37
# 댓글수 : 10
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 난 이재명을 지지 하지 않아!
# 작성자 : Mangazine
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=679000080
# 업로드 시간 : 2021-04-25
# 조회수 : 398
# 추천수 :
# 댓글수 : 1
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명이 며칠 전 '한 천명만 자르면 된다고 한다' 한 거 보면 정확히 아는 거 같았어요
# 작성자 : 기이임밥
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678995598
# 업로드 시간 : 2021-04-25
# 조회수 : 1172
# 추천수 : 15
# 댓글수 : 0
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명,  '재산비례 벌금제'  주장
# 작성자 : 연아때메화이트골드
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678982137
# 업로드 시간 : 2021-04-25
# 조회수 : 1884
# 추천수 : 49
# 댓글수 : 18
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 “핀란드형 재산비례 벌금제 도입해야”
# 작성자 : shabrina
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678974751
# 업로드 시간 : 2021-04-25
# 조회수 : 2696
# 추천수 : 87
# 댓글수 : 20
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : <문재인과 이재명의 환상적 백신외교>
# 작성자 : 두밀두밀
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678973210
# 업로드 시간 : 2021-04-25
# 조회수 : 797
# 추천수 : 2
# 댓글수 : 6
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 더팩▷이재명 지사 앞에서 국민밉상 윤희숙 알짱거리다
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678970956
# 업로드 시간 : 2021-04-25
# 조회수 : 725
# 추천수 : 2
# 댓글수 : 5
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이탄희, 이재명의 재산비례 벌금제 반가운 주장입니다
# 작성자 : 아빠는외계인
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678969444
# 업로드 시간 : 2021-04-25
# 조회수 : 5255
# 추천수 : 267
# 댓글수 : 38
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 비난한 당원 제명에..與게시판, 친문 당원들 시끌
# 작성자 : Jennie
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678963283
# 업로드 시간 : 2021-04-25
# 조회수 : 691
# 추천수 : 16
# 댓글수 : 5
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 문화▷이재명 “피고인 경제력 따라 벌금도 차등 둬야”
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678962870
# 업로드 시간 : 2021-04-25
# 조회수 : 352
# 추천수 : 6
# 댓글수 : 6
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 "대선 노리고 공공기관 이전? 표 생각했으면 모른 척했지"
# 작성자 : 기이임밥
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678949905
# 업로드 시간 : 2021-04-25
# 조회수 : 450
# 추천수 : 7
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 유튜브 이재명 지사 클립 댓글 보니 이미지가 나쁘지 않네요
# 작성자 : 기이임밥
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678944821
# 업로드 시간 : 2021-04-25
# 조회수 : 252
# 추천수 : 3
# 댓글수 : 5
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 유승민 "이재명 정책은 허구 경제는 내가 제일"
# 작성자 : 막내야
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678944482
# 업로드 시간 : 2021-04-25
# 조회수 : 3330
# 추천수 : 28
# 댓글수 : 75
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 전북교수 40여명 이재명 지지선언
# 작성자 : 서둘
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678939873
# 업로드 시간 : 2021-04-25
# 조회수 : 658
# 추천수 : 12
# 댓글수 : 0
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : '이재명 음해' 가짜뉴스 다시 떠올라
# 작성자 : 솔아란
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678931629
# 업로드 시간 : 2021-04-25
# 조회수 : 519
# 추천수 : 2
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 한국▷이재명 기본소득 참여 요청에 모두 74개 지방정부 화답
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678926893
# 업로드 시간 : 2021-04-25
# 조회수 : 672
# 추천수 : 4
# 댓글수 : 4
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 “쥐 잡는데 흑묘, 백묘 없어"
# 작성자 : 냥발바닥
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678908118
# 업로드 시간 : 2021-04-25
# 조회수 : 1216
# 추천수 : 13
# 댓글수 : 6
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 비올때 차선이 안보인다. 이재명이 이거 공약하면 좋겠다.
# 작성자 : [N🔴]봉자쌀롱
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678894420
# 업로드 시간 : 2021-04-24
# 조회수 : 396
# 추천수 : 4
# 댓글수 : 4
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 헤경▷이재명 “문프가 이끌어온 수레 힘껏 밀어갈 것”
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678865320
# 업로드 시간 : 2021-04-24
# 조회수 : 613
# 추천수 : 13
# 댓글수 : 5
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 '내가 한 행정의 책임은 내가 진다.'
# 작성자 : 로이거
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678856761
# 업로드 시간 : 2021-04-24
# 조회수 : 8213
# 추천수 : 205
# 댓글수 : 48
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명의 시원함...
# 작성자 : 다저스월시우승
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678850827
# 업로드 시간 : 2021-04-24
# 조회수 : 809
# 추천수 : 5
# 댓글수 : 16
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 뉴스1▷이재명 “백신 예산낭비 돼도 남는 것 나아”
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678845705
# 업로드 시간 : 2021-04-24
# 조회수 : 443
# 추천수 : 6
# 댓글수 : 3
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 '주호영 주장은 명백한 거짓말'
# 작성자 : 막내야
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678835661
# 업로드 시간 : 2021-04-24
# 조회수 : 5281
# 추천수 : 92
# 댓글수 : 20
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 어설픈 관용과 용서는 참극을 부른다 - 이재명
# 작성자 : 탈네모
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678832221
# 업로드 시간 : 2021-04-24
# 조회수 : 3094
# 추천수 : 79
# 댓글수 : 11
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 강원▷이재명 '국짐 수구 복귀' 강원일보가 최초 보도!
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678830511
# 업로드 시간 : 2021-04-24
# 조회수 : 615
# 추천수 : 6
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 정세균의 러시아 백신, 이재명 발언
# 작성자 : 로그인을하라고?
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678830567
# 업로드 시간 : 2021-04-24
# 조회수 : 635
# 추천수 : 2
# 댓글수 : 3
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 시원하게 국혐 패는 이재명지사
# 작성자 : 서둘
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678829203
# 업로드 시간 : 2021-04-24
# 조회수 : 9802
# 추천수 : 217
# 댓글수 : 14
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 추미애든 이재명이든 다른 거 다 필요 없고
# 작성자 : G-2
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511713602&document_srl=678824613
# 업로드 시간 : 2021-04-24
# 조회수 : 486
# 추천수 : 1
# 댓글수 : 0
#
#
# =====   다음 페이지로 넘어갑니다.   =====
# =====   계속 검색을 시도합니다.   =====
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 지사 《기본주택 이슈선점》
# 작성자 : 🎗💙🍊수키🍊💙🎗
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511707786&document_srl=678689839
# 업로드 시간 : 2021-04-23
# 조회수 : 482
# 추천수 : 11
# 댓글수 : 4
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 문재인 대통령께 아쉬운점 딱 한가지.. (ft.이재명에 기대하는점)
# 작성자 : [N🔴]오!또해영
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511707786&document_srl=678680771
# 업로드 시간 : 2021-04-23
# 조회수 : 375
# 추천수 :
# 댓글수 : 29
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 자료▷김부선 보고서와 이재명 후보 해명 자료
# 작성자 : ☆기사엄선☆
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511707786&document_srl=678670324
# 업로드 시간 : 2021-04-23
# 조회수 : 796
# 추천수 :
# 댓글수 : 8
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 이재명 "민주당 떠난 적도, 그럴 생각도 없다"
# 작성자 : 서둘
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511707786&document_srl=678656910
# 업로드 시간 : 2021-04-23
# 조회수 : 592
# 추천수 : 14
# 댓글수 : 2
#
#
# 크롤링 도메인 :  딴지
# 크롤링 키워드 :  이재명
# 게시물 제목 : 중요한 건 경선대회인데 만약 사면발이가 이재명을
# 작성자 : HallelujahEssaim
# 게시물 url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511707786&document_srl=678652344
# 업로드 시간 : 2021-04-23
# 조회수 : 575
# 추천수 :
# 댓글수 : 3
#
#
# =====   다음 페이지로 넘어갑니다.   =====
# =====   계속 검색을 시도합니다.   =====

# %%
text2 = []
com_text2 = []

# %%
batch_cnt = 0

print(f"======   키워드 게시물 총 {len(url2)}개입니다.   =====")
print(f"=====   총 {math.ceil(len(url2) / 10)} 개의 batch로 나눠 진행합니다.   ======")

while True :
    print(f"현재 {batch_cnt+1}번째 batch 진행 중...")
    
    url_list = [x for x in url2[batch_cnt*10:batch_cnt*10+10]] # 10개씩 끊기
    
    batch_user2 = []
    batch_text2 = []
    batch_com_text2 = []
    
    for url in tqdm(url_list) :
        print("url :", url)

        com_cnt = 0

        while True :

            com_cnt += 1
            
            post_code = 0


            try :

                driver.get(url)
                driver.implicitly_wait(20)
                time.sleep(3)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')

                text1 = soup.find(name='div', attrs={'class':'read_content'}).text.strip().replace("\n", "")
                com_user_list = soup.find(name='div', attrs={'id':'cmt_list'}).find_all(name='div', attrs={'class':'fbItem_left'})
                com_text_list = soup.find(name='div', attrs={'id':'cmt_list'}).find_all(name='div', attrs={'class':'fbItem_right'})
                tmp_list = []
                user_list = []

                for k in range(len(com_user_list)) :

                    string = "작성자 : " + com_user_list[k].text.strip().replace("\n","").replace("\t", "") + " :: " + com_text_list[k].text.strip().replace("\n","").replace("\t", "")
                    com_list.append(string)
                    user_list.append(com_user_list[k].find(name='h4',attrs={'class':'author'}).text.strip().replace("\n","").replace("\t", "").replace("본문 글쓴이",""))

                for k in range(len(com_user_list)) :
            #         print(com_user_list[k].text.strip().replace("\n",""),com_text_list[k].text.strip().replace("\n",""))
                    string = com_user_list[k].text.strip().replace("\n","").replace("\t", "") + " : " + com_text_list[k].text.strip().replace("\n","").replace("\t", "")
                    tmp_list.append(string)
                com_text1 = tmp_list
                
                
                print("본문 :", text1)
                print("댓글 유저 :", user_list)
                print("댓글 :", com_text1)
                print("\n")

                batch_text2.append(text1)
                batch_user2.append(user_list)
                batch_com_text2.append(com_text1)
                
                post_code = 1

                break

            except : # 글이 삭제된 경우
                
                except_cnt = 0
                
                while except_cnt <= 2 :
                    except_code = 0
                    
                    try :
                        except_cnt += 1
                        
                        driver.refresh()
                        driver.refresh()
                        driver.get(url)
                        driver.implicitly_wait(20)
                        time.sleep(3)

                        html = driver.page_source
                        soup = BeautifulSoup(html, 'html.parser')

                        text1 = soup.find(name='div', attrs={'class':'read_content'}).text.strip().replace("\n", "")
                        com_user_list = soup.find(name='div', attrs={'id':'cmt_list'}).find_all(name='div', attrs={'class':'fbItem_left'})
                        com_text_list = soup.find(name='div', attrs={'id':'cmt_list'}).find_all(name='div', attrs={'class':'fbItem_right'})
                        user_list = []
                        tmp_list = []
                        
                        for k in range(len(com_user_list)) :

                            string = "작성자 : " + com_user_list[k].text.strip().replace("\n","").replace("\t", "") + " :: " + com_text_list[k].text.strip().replace("\n","").replace("\t", "")
                            com_list.append(string)
                            user_list.append(com_user_list[k].find(name='h4',attrs={'class':'author'}).text.strip().replace("\n","").replace("\t", "").replace("본문 글쓴이",""))

                        for k in range(len(com_user_list)) :
                    #         print(com_user_list[k].text.strip().replace("\n",""),com_text_list[k].text.strip().replace("\n",""))
                            string = com_user_list[k].text.strip().replace("\n","").replace("\t", "") + " : " + com_text_list[k].text.strip().replace("\n","").replace("\t", "")
                            tmp_list.append(string)
                        com_text1 = tmp_list


                        print("본문 :", text1)
                        print("댓글 유저 :", user_list)
                        print("댓글 :", com_text1)
                        print("\n")

                        batch_text2.append(text1)
                        batch_user2.append(user_list)
                        batch_com_text2.append(com_text1)
                        
                        except_code = 1
                        break
                    except :
                        pass
                
            if except_code == 0 :
                driver.refresh()

                text1 = "삭제된 게시물"
                user_list = [""]
                com_text1 = "삭제된 게시물"


                print("본문 :", text1)
                print("댓글 유저:", user_list)
                print("댓글 :", com_text1)
                print("\n")

                batch_text2.append(text1)
                batch_user2.append(user_list)
                batch_com_text2.append(com_text1)

                break
    
    for i in range(len(batch_text2)) :
        text2.append(batch_text2[i])
        com_text2.append(batch_com_text2[i])
        com_user2.append(batch_user2[i])
        
    if batch_cnt*10+10 >= len(url2) :
        break
        
    batch_cnt += 1

print("모든 크롤링 작업을 완료하였습니다.")
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# ======   키워드 게시물 총 86개입니다.   =====
# =====   총 9 개의 batch로 나눠 진행합니다.   ======
# 현재 1번째 batch 진행 중...
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679613967
#  10%|████████▎                                                                          | 1/10 [00:16<02:29, 16.57s/it]
# 본문 : 다음원래 저래서 이용했는데 얼마만인지..정봉주 역시 이슈력있네요.
# 댓글 유저 : []
# 댓글 : []
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679607393
#  20%|████████████████▌                                                                  | 2/10 [01:05<04:44, 35.61s/it]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679601328
#  30%|████████████████████████▉                                                          | 3/10 [02:05<05:25, 46.53s/it]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679588912
#  40%|█████████████████████████████████▏                                                 | 4/10 [03:06<05:14, 52.50s/it]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679586165
#  50%|█████████████████████████████████████████▌                                         | 5/10 [03:15<03:03, 36.80s/it]
# 본문 : 오픈채팅방을 만들어보았습니다.분란 일으키려는 의도는 아니니 원치 않는 분들의 의사도 존중합니다. 함께 하시지요! 같이 만들어 봅시다! [민주평화광장] 이재명과 함께https://open.kakao.com/o/gonEGuad1 of 1
# 댓글 유저 : []
# 댓글 : []
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679583323
#  60%|█████████████████████████████████████████████████▊                                 | 6/10 [03:22<01:45, 26.49s/it]
# 본문 : 성별갈등은 존재하는 갈등입니다. 여론조사를 통해 2030세대가 뽑은 가장 큰 사회갈등으로 꼽힌지 몇 년이 되었는데 그동안 이를 인정하지 않았다는 것부터 우리사회가 성찰해야할 대목입니다. 청년여성도 청년남성도 각각 성차별적 정책이 있다고 호소하고 있다면 있는그대로 내어놓고 토론하고 합의가능한 공정한 정책을 도출하면 됩니다. 가장 나쁜 것은 갈등을 회피하고 방치하는 것입니다.​비단 몇몇 군 관련 정책으로 청년남성의 마음을 돌리려는 시도는 성공하기 어려워 보입니다. 다짜고짜 우는 아이 떡 하나 주는 방식으로는 모두에게 외면받습니다. 청년세대는 '공정'을 원하지 '특혜'를 원하고 있지 않습니다. 병사 최저임금, 모든 폭력으로부터의 안전 강화, 경력단절 해소 및 남녀 육아휴직 확대, 차별과 특혜없는 공정한 채용 등 성별불문 공히 동의하는 정책 의제도 많습니다. 회피하지 않고 직면한다면 문제를 해결할 수 있습니다.   이재명이 올린 글 원문입니다.  여기 어디에 군 가산점을 까는 내용이 있다는 거죠??
# 댓글 유저 : []
# 댓글 : []
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679579072
#  70%|██████████████████████████████████████████████████████████                         | 7/10 [04:18<01:49, 36.36s/it]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679575427
#  80%|██████████████████████████████████████████████████████████████████▍                | 8/10 [05:17<01:26, 43.35s/it]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679573195
#  90%|██████████████████████████████████████████████████████████████████████████▋        | 9/10 [06:18<00:48, 48.90s/it]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679550510
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:05<00:00, 42.51s/it]
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# 현재 2번째 batch 진행 중...
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679545550
#  10%|████████▎                                                                          | 1/10 [00:05<00:45,  5.08s/it]
# 본문 : 아니면 지금이 대선기간인가요? 적당히들 합시다. 상관없는 이슈에 민주당 까고 이재명 지사 띄우면 이재명 지사에게 득이 될까요 실이 될까요? 요즘 이재명 지사 글 쓰는 사람들 보면 가끔 지지자인지 아니면 교묘한 안티인지 헷갈리네요.
# 댓글 유저 : []
# 댓글 : []
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679544776
#  20%|████████████████▌                                                                  | 2/10 [01:06<05:07, 38.41s/it]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679532472
#  30%|████████████████████████▉                                                          | 3/10 [02:02<05:25, 46.51s/it]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679530839
#  40%|█████████████████████████████████▏                                                 | 4/10 [02:58<05:00, 50.12s/it]
# 본문 : 삭제된 게시물
# 댓글 유저: ['']
# 댓글 : 삭제된 게시물
#
#
# url : https://www.ddanzi.com/index.php?_filter=search&mid=free&search_target=title&search_keyword=%EC%9D%B4%EC%9E%AC%EB%AA%85&division=-511725076&document_srl=679524060

# %%
# # 각 url로 이동해서 게시글 text와 com_text 수집

# for url in url2 :
#     print("url :", url)
    
#     com_cnt = 0
    
#     while True :
        
#         com_cnt += 1
        
        
#         try :

#             driver.get(url)
#             driver.implicitly_wait(20)
#             time.sleep(3)

#             html = driver.page_source
#             soup = BeautifulSoup(html, 'html.parser')

#             text1 = soup.find(name='div', attrs={'class':'read_content'}).text.strip().replace("\n", "")
#             com_user_list = soup.find(name='div', attrs={'id':'cmt_list'}).find_all(name='div', attrs={'class':'fbItem_left'})
#             com_text_list = soup.find(name='div', attrs={'id':'cmt_list'}).find_all(name='div', attrs={'class':'fbItem_right'})
#             tmp_list = []

#             for k in range(len(com_user_list)) :
#         #         print(com_user_list[k].text.strip().replace("\n",""),com_text_list[k].text.strip().replace("\n",""))
#                 string = com_user_list[k].text.strip().replace("\n","").replace("\t", "") + " : " + com_text_list[k].text.strip().replace("\n","").replace("\t", "")
#                 tmp_list.append(string)
#             com_text1 = tmp_list

#             print("본문 :", text1)
#             print("댓글 :", tmp_list)
#             print("\n")

#             text2.append(text1)
#             com_text2.append(com_text1)
            
#             break

#         except : # airbnb 인터넷이 끊기는 경우

#             driver.refresh()
#             driver.get(url)
#             driver.implicitly_wait(20)
#             time.sleep(3)

#             html = driver.page_source
#             soup = BeautifulSoup(html, 'html.parser')

#             text1 = soup.find(name='div', attrs={'class':'read_content'}).text.strip().replace("\n", "")
#             com_user_list = soup.find(name='div', attrs={'id':'cmt_list'}).find_all(name='div', attrs={'class':'fbItem_left'})
#             com_text_list = soup.find(name='div', attrs={'id':'cmt_list'}).find_all(name='div', attrs={'class':'fbItem_right'})
#             tmp_list = []

#             for k in range(len(com_user_list)) :
#         #         print(com_user_list[k].text.strip().replace("\n",""),com_text_list[k].text.strip().replace("\n",""))
#                 string = com_user_list[k].text.strip().replace("\n","").replace("\t", "") + " : " + com_text_list[k].text.strip().replace("\n","").replace("\t", "")
#                 tmp_list.append(string)
#             com_text1 = tmp_list

#             print("본문 :", text1)
#             print("댓글 :", tmp_list)
#             print("\n")

#             text2.append(text1)
#             com_text2.append(com_text1)
            
#             break

# %%
print("Let's Test")

# %%
df = pd.DataFrame()

df['domain'] = pd.Series(domain2)
df['keyword'] = pd.Series(keyword2)
df['title'] = pd.Series(title2)
df['user_name'] = pd.Series(user2)
df['url'] = pd.Series(url2)
df['date'] = pd.Series(time2)
df['view_cnt'] = pd.Series(view_cnt2)
df['like_cnt'] = pd.Series(like_cnt2)
df['user_text'] = pd.Series(text2)
df['com_cnt'] = pd.Series(com_cnt2)
df['com_text'] = pd.Series(com_text2)

df

# %%
# csv 형태로 저장하기
df.to_csv(fc_name,encoding="utf-8-sig",index=False)

e_time = time.time( )
t_time = e_time - s_time

print("\n")
print("=" *80)
print("1.총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("2.파일 저장 완료: csv 파일명 : %s " %fc_name)

driver.quit()
sys.exit("프로그램을 종료합니다.")

# %%
df['time'].hist();
