# %%
import pandas as pd

df = pd.read_csv("2021-04-21-2021-04-28_ddanzi.csv")
df
# Out:
#      domain  keyword                                              title  \
# 0    딴지_인증글      NaN             개혁의 완성은 꼭 한동수 검찰총장. 정청래 법사위원장이 되셔야합니다.
# 1    딴지_인증글      NaN                              현직 AZ 접종후 30분간 대기중입니다
# 2    딴지_인증글      NaN                                   재용아 넌 좋겠다....ㄷㄷㄷ
# 3    딴지_인증글      NaN                                               투표완료
# 4    딴지_인증글      NaN                               75년식 아재 셀후 대란 종식 도전~
# ..      ...      ...                                                ...
# 160  딴지_인증글      NaN                                [꽈배기 인증] 아. 감사합니다!!
# 161  딴지_인증글      NaN                                   귀한 선물을 받았습니다. 😍👍
# 162  딴지_인증글      NaN             [국민청원동의요청]조국정경심관련검찰야당언론사건조작있었다면공수처수사하라
# 163  딴지_인증글      NaN          (후기) 오늘 독일에서 코로나 백신 1차 접종 마치고 왔습니다. (화이자)
# 164  딴지_인증글      NaN  [[뉴있저] 최성해 '비례대표' 제안?...커지는 정경심 2심 진실게임 공방] 왜 ...
#
#         writer                                                url        time  \
# ...

# %%
keyword = ['이낙연', '이재명']

df1, df2 = pd.DataFrame(), pd.DataFrame()

list_a, list_b = [], []

for i in range(len(df)) :
    if keyword[0] in df['title'][i] :
        list_a.append(i)
        
    if keyword[1] in df['title'][i] :
        list_b.append(i)

print(len(list_a), len(list_b))
# Out:
# 0 0

# %%
keyword = ['이낙연', '이재명']

df1, df2 = pd.DataFrame(), pd.DataFrame()

list_a, list_b = [], []

for i in range(len(df)) :
    print(i, df['content'][i])
    try :
        if keyword[0] in df['content'][i] :
            list_a.append(i)
    except :
        pass
    
    try :
        if keyword[1] in df['content'][i] :
            list_b.append(i)
    except :
        pass
        
print(len(list_a), len(list_b))
# Out:
# 0 개혁의 완성은 꼭 한동수 검찰총장. 정청래 법사위원장이 되셔야합니다.당대표.-우원식. 검찰총장-한동수, 원내대표-윤호중. 법사위원장-정청래, 최고위원장-김용민 꼭 이렇게 되야 합니다.. 그래야만 개혁의 완성이 가능합니다. 아울러 법사위원 3명도 갈아치워야 합니다.백해련. 소병철. 송기헌 검새 3마리를 이재정 또는 이수진. 이탄희. 황운하 의원으로 교체하고문체부 언론TF 에 이낙연. 윤영찬. 노웅래 기레기출신 3마리를 내쫒고언론개혁의 적극적인 의원으로 교체해햐 합니다. 그러면 개혁 가능합니다.결론은 수박들을 내치고 개혁파들을 중용해야 하는겁니다. 근데 그게 수박들의 발악으로 안돼는 것입니다.수박들은 국회의원 뺏지만 중요하고 국민들의 바램은 전혀 생각하지 않는 인간들입니다. 꼭 이들을 내쫒아야 합니다...수박들은 단체로 윤호중의원을 협박하고 있습니다. 법사위원장에 박광온이나 박완주를 앉히라고 난리치고 있죠.,윤호중 의원님은 눈치보지 말고 정청래 의원님으로 결단을 내리셔야 합니다. 검찰총장은 검사출신이 아닌 한동수 감찰부장. 이분이 해야 강한 개혁을 할수 있습니다.조국 장관님이 가장 신뢰하셨던 분입니다..김용민 의원께서 비검찰출신인 한동수 감찰부장이 해야 개혁가능하다 하셨죠..만약 한동수 이분이 안될경우. 차선은 임은정 감찰과장 이분이라도 해야 합니다.이성윤 중앙지검장 이분은 약합니다. 한동수. 임은정이 안될경우 그나마 이성윤인데. 이성윤 불안합니다...이사람은 검사에요..지금이야 윤석열 반대편에 선걸로 우리편인듯 보이지만 솔직히 공이 없어요...윤짜장이 나간지가 언제인데 아무것도 안하고 있는게 이상해요이성윤도 검사출신입니다. 어디로 튈지 모르는 분입니다.가장 안전하고 개혁드라이브 걸수 있는 분은 한동수 감찰부장입니다.. 그다음이 임은정 감찰과장 입니다..
# 1 아직은 아무런 이상없네요 아직 대기시간이 18분 남았네요
# ...

# %%
list_b
# Out:
# []

# %%
df['title']
# Out:
# 0                 개혁의 완성은 꼭 한동수 검찰총장. 정청래 법사위원장이 되셔야합니다.
# 1                                  현직 AZ 접종후 30분간 대기중입니다
# 2                                       재용아 넌 좋겠다....ㄷㄷㄷ
# 3                                                   투표완료
# 4                                   75년식 아재 셀후 대란 종식 도전~
#                              ...
# 160                                  [꽈배기 인증] 아. 감사합니다!!
# 161                                     귀한 선물을 받았습니다. 😍👍
# 162               [국민청원동의요청]조국정경심관련검찰야당언론사건조작있었다면공수처수사하라
# 163            (후기) 오늘 독일에서 코로나 백신 1차 접종 마치고 왔습니다. (화이자)
# 164    [[뉴있저] 최성해 '비례대표' 제안?...커지는 정경심 2심 진실게임 공방] 왜 ...
# Name: title, Length: 165, dtype: object
